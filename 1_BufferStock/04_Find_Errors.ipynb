# %% [markdown]
# # Find Errors

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Settings](#toc1_)
# - 2. [Run](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch

# %%
import matplotlib.pyplot as plt
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({'axes.grid':True,'grid.color':'black','grid.alpha':'0.25','grid.linestyle':'--'})
plt.rcParams.update({'font.size': 14})

# %%
from EconDLSolvers import choose_gpu

# %%
from BufferStockModel import BufferStockModelClass

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Settings](#toc0_)

# %%
algoname = 'DeepFOC'
par = {}
train = {'K_time':0.5}

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Run](#toc0_)

# %%
device = choose_gpu()
# Out:
# GPU 0: 44.40GB free [NVIDIA L40]
# Best GPU: 0

# %%
model = BufferStockModelClass(algoname=algoname,device=device,par=par,train=train)
model.solve(do_print=True)
# Out:
# started solving: 2026-01-31 00:32:33
# k =     0 of inf: sim.R =   -34.37154388 [best:   -34.37154388] [3.4 secs] [value_epochs =   0] [policy_epochs =  15] [  0.06 mins] [policy_lr = 1.0e-03]
# k =    10 of inf: sim.R =     2.02215052 [best:     2.02215052] [3.2 secs] [value_epochs =   0] [policy_epochs =  15] [  0.15 mins] [policy_lr = 1.0e-03]
# k =    20 of inf: sim.R =     2.04579163 [best:     2.04579163] [3.2 secs] [value_epochs =   0] [policy_epochs =  15] [  0.25 mins] [policy_lr = 1.0e-03]
# k =    30 of inf: sim.R =     2.05556679 [best:     2.05556679] [3.2 secs] [value_epochs =   0] [policy_epochs =  15] [  0.34 mins] [policy_lr = 1.0e-03]
# k =    40 of inf: sim.R =     2.06055999 [best:     2.06055999] [3.2 secs] [value_epochs =   0] [policy_epochs =  15] [  0.43 mins] [policy_lr = 1.0e-03]
# k =    50 of inf: sim.R =     2.05900240 [best:     2.06055999] [0.4 secs] [value_epochs =   0] [policy_epochs =   7] [  0.48 mins] [policy_lr = 9.9e-04] no improvements in 0.1 mins
# Terminating after 56 episodes, max time 0.5 mins reached
# R = 2.0621, time = 0.6 mins, iter = 56, policy epochs = 14.54, value epochs = 0.00
# Simulating multiple Rs
