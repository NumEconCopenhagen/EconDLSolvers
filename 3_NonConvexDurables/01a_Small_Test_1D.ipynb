# %% [markdown]
# # Small Test D1

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Imports](#toc1_)
# - 2. [Settings](#toc2_)
# - 3. [DP](#toc3_)
# - 4. [DL](#toc4_)
# - 5. [Compare life-cycle](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Imports](#toc0_)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE' # without this python may crash when plotting from matplotlib
import numpy as np

import matplotlib.pyplot as plt
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({'axes.grid':True,'grid.color': 'black','grid.alpha':'0.25','grid.linestyle': '--'})
plt.rcParams.update({'font.size':14})
plt.rcParams.update({'font.family':'serif'})

from EconDLSolvers import choose_gpu
from NonConvexDurablesModel import NonConvexDurablesModelClass
from NonConvexDurablesModelVFI import NonConvexDurablesModelVFIClass

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Settings](#toc0_)

# %%
par = {'full':False}
DO_DP = True
LOAD_DP = False

# %% [markdown]
# ## 3. <a id='toc3_'></a>[DP](#toc0_)

# %%
filename = 'NonConvexDurablesModel_1D_DP_small'

if DO_DP:

    if LOAD_DP:
        model_dp = NonConvexDurablesModelVFIClass(name=filename,load=True)
    else:
        model_dp = NonConvexDurablesModelVFIClass(par=par,vfi={'Nm':100,'Na':100,'Np':100,'Nn':100})
        model_dp.link_to_cpp()
        model_dp.solve()
        model_dp.save(f'{model_dp.savefolder}/{filename}.p')

    model_dp.simulate_R()
    print(f'{model_dp.sim.R = :12.8f}')
# Out:
# model_dp.sim.R =  -5.94599893

# %% [markdown]
# ## 4. <a id='toc4_'></a>[DL](#toc0_)

# %%
device = choose_gpu()
# Out:
# No GPU available, using CPU

# %%
models_dl = {}

# %%
for use_FOC in [False,True]:

    print(f'Using FOC: {use_FOC}')

    # a. setup
    model_dl = NonConvexDurablesModelClass(device=device,algoname='DeepVPDDC',
                                        par=par,train={'K_time':10.0,
                                                        'use_FOC':use_FOC,
                                                        'start_train_policy':-1,
                                                        'sim_R_freq':50})

    # b. solve and simulate
    model_dl.solve(do_print=True)
    model_dl.more_simulation_outcomes()
    model_dl.euler_errors_DL()
    
    # c. save
    models_dl[use_FOC] = model_dl

    print('')
# Out:
# Using FOC: False
# started solving: 2026-02-06 23:28:25
# k =     0 of inf: sim.R =    -7.26562977 [best:    -7.26562977] [2.0 secs] [value_epochs = 121] [policy_epochs =  15] [  0.03 mins] [policy_lr = 1.0e-03] [value_lr = 1.0e-03]
# k =    50 of inf: sim.R =    -5.95600462 [best:    -5.95600462] [2.1 secs] [value_epochs = 150] [policy_epochs =  15] [  0.88 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   100 of inf: sim.R =    -5.94593811 [best:    -5.94593811] [1.5 secs] [value_epochs =  45] [policy_epochs =  15] [  1.61 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   150 of inf: sim.R =    -5.94520617 [best:    -5.94520617] [1.5 secs] [value_epochs =  39] [policy_epochs =  15] [  2.06 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   200 of inf: sim.R =    -5.94500875 [best:    -5.94500875] [1.7 secs] [value_epochs =  75] [policy_epochs =  15] [  2.51 mins] [policy_lr = 9.8e-04] [value_lr = 9.8e-04]
# k =   250 of inf: sim.R =    -5.94477367 [best:    -5.94477367] [1.7 secs] [value_epochs =  72] [policy_epochs =  15] [  2.93 mins] [policy_lr = 9.8e-04] [value_lr = 9.8e-04]
# k =   300 of inf: sim.R =    -5.94475698 [best:    -5.94475698] [1.5 secs] [value_epochs =  38] [policy_epochs =  15] [  3.40 mins] [policy_lr = 9.7e-04] [value_lr = 9.7e-04]
# k =   350 of inf: sim.R =    -5.94463015 [best:    -5.94463015] [1.7 secs] [value_epochs =  72] [policy_epochs =  15] [  3.85 mins] [policy_lr = 9.7e-04] [value_lr = 9.7e-04]
# k =   400 of inf: sim.R =    -5.94461775 [best:    -5.94461775] [1.5 secs] [value_epochs =  38] [policy_epochs =  15] [  4.30 mins] [policy_lr = 9.6e-04] [value_lr = 9.6e-04]
# k =   450 of inf: sim.R =    -5.94457245 [best:    -5.94457245] [1.7 secs] [value_epochs =  76] [policy_epochs =  15] [  4.73 mins] [policy_lr = 9.6e-04] [value_lr = 9.6e-04]
# k =   500 of inf: sim.R =    -5.94448185 [best:    -5.94448185] [1.5 secs] [value_epochs =  34] [policy_epochs =  15] [  5.16 mins] [policy_lr = 9.5e-04] [value_lr = 9.5e-04]
# k =   550 of inf: sim.R =    -5.94449854 [best:    -5.94448185] [0.9 secs] [value_epochs =  73] [policy_epochs =  15] [  5.56 mins] [policy_lr = 9.5e-04] [value_lr = 9.5e-04] no improvements in 0.4 mins
# k =   600 of inf: sim.R =    -5.94451427 [best:    -5.94448185] [0.6 secs] [value_epochs =  47] [policy_epochs =  15] [  5.98 mins] [policy_lr = 9.4e-04] [value_lr = 9.4e-04] no improvements in 0.8 mins
# k =   650 of inf: sim.R =    -5.94453764 [best:    -5.94448185] [0.9 secs] [value_epochs = 112] [policy_epochs =  15] [  6.34 mins] [policy_lr = 9.4e-04] [value_lr = 9.4e-04] no improvements in 1.2 mins
# k =   700 of inf: sim.R =    -5.94463778 [best:    -5.94448185] [0.5 secs] [value_epochs =  33] [policy_epochs =  15] [  6.78 mins] [policy_lr = 9.3e-04] [value_lr = 9.3e-04] no improvements in 1.6 mins
# k =   750 of inf: sim.R =    -5.94457245 [best:    -5.94448185] [0.8 secs] [value_epochs = 113] [policy_epochs =   6] [  7.16 mins] [policy_lr = 9.3e-04] [value_lr = 9.3e-04] no improvements in 2.0 mins
# k =   800 of inf: sim.R =    -5.94454622 [best:    -5.94448185] [0.7 secs] [value_epochs =  74] [policy_epochs =  14] [  7.57 mins] [policy_lr = 9.2e-04] [value_lr = 9.2e-04] no improvements in 2.4 mins
# k =   850 of inf: sim.R =    -5.94460344 [best:    -5.94448185] [0.5 secs] [value_epochs =  34] [policy_epochs =  15] [  7.98 mins] [policy_lr = 9.2e-04] [value_lr = 9.2e-04] no improvements in 2.8 mins
# k =   900 of inf: sim.R =    -5.94456768 [best:    -5.94448185] [0.7 secs] [value_epochs =  72] [policy_epochs =  15] [  8.43 mins] [policy_lr = 9.1e-04] [value_lr = 9.1e-04] no improvements in 3.3 mins
# k =   950 of inf: sim.R =    -5.94449711 [best:    -5.94448185] [0.9 secs] [value_epochs = 113] [policy_epochs =  15] [  8.87 mins] [policy_lr = 9.1e-04] [value_lr = 9.1e-04] no improvements in 3.7 mins
# k =  1000 of inf: sim.R =    -5.94461250 [best:    -5.94448185] [0.5 secs] [value_epochs =  35] [policy_epochs =  15] [  9.21 mins] [policy_lr = 9.0e-04] [value_lr = 9.0e-04] no improvements in 4.1 mins
# k =  1050 of inf: sim.R =    -5.94454908 [best:    -5.94448185] [0.7 secs] [value_epochs =  75] [policy_epochs =  15] [  9.60 mins] [policy_lr = 9.0e-04] [value_lr = 9.0e-04] no improvements in 4.5 mins
# k =  1100 of inf: sim.R =    -5.94457960 [best:    -5.94448185] [0.5 secs] [value_epochs =  39] [policy_epochs =  15] [  9.98 mins] [policy_lr = 9.0e-04] [value_lr = 9.0e-04] no improvements in 4.8 mins
# Terminating after 1105 episodes, max time 10.0 mins reached
# R = -5.9445, time = 10.0 mins, iter = 1105, policy epochs = 14.05, value epochs = 58.51
# Simulating multiple Rs
#
# Using FOC: True
# started solving: 2026-02-06 23:38:27
# k =     0 of inf: sim.R =    -7.21721029 [best:    -7.21721029] [2.3 secs] [value_epochs = 150] [policy_epochs =  15] [  0.04 mins] [policy_lr = 1.0e-03] [value_lr = 1.0e-03]
# k =    50 of inf: sim.R =    -5.94750881 [best:    -5.94750881] [2.3 secs] [value_epochs = 150] [policy_epochs =  15] [  1.07 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   100 of inf: sim.R =    -5.94546700 [best:    -5.94546700] [1.9 secs] [value_epochs =  75] [policy_epochs =  15] [  2.08 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   150 of inf: sim.R =    -5.94497299 [best:    -5.94497299] [1.9 secs] [value_epochs = 101] [policy_epochs =  15] [  2.78 mins] [policy_lr = 9.9e-04] [value_lr = 9.9e-04]
# k =   200 of inf: sim.R =    -5.94485950 [best:    -5.94485950] [2.1 secs] [value_epochs = 111] [policy_epochs =  15] [  3.50 mins] [policy_lr = 9.8e-04] [value_lr = 9.8e-04]
# k =   250 of inf: sim.R =    -5.94477081 [best:    -5.94477081] [1.8 secs] [value_epochs =  61] [policy_epochs =  15] [  4.18 mins] [policy_lr = 9.8e-04] [value_lr = 9.8e-04]
# k =   300 of inf: sim.R =    -5.94467211 [best:    -5.94467211] [1.6 secs] [value_epochs =  36] [policy_epochs =  15] [  4.81 mins] [policy_lr = 9.7e-04] [value_lr = 9.7e-04]
# k =   350 of inf: sim.R =    -5.94461250 [best:    -5.94461250] [1.7 secs] [value_epochs =  60] [policy_epochs =  15] [  5.48 mins] [policy_lr = 9.7e-04] [value_lr = 9.7e-04]
# k =   400 of inf: sim.R =    -5.94466114 [best:    -5.94461250] [1.0 secs] [value_epochs = 112] [policy_epochs =  15] [  6.19 mins] [policy_lr = 9.6e-04] [value_lr = 9.6e-04] no improvements in 0.7 mins
# k =   450 of inf: sim.R =    -5.94457722 [best:    -5.94457722] [1.9 secs] [value_epochs =  76] [policy_epochs =  15] [  6.91 mins] [policy_lr = 9.6e-04] [value_lr = 9.6e-04]
# k =   500 of inf: sim.R =    -5.94455767 [best:    -5.94455767] [2.1 secs] [value_epochs = 125] [policy_epochs =  15] [  7.64 mins] [policy_lr = 9.5e-04] [value_lr = 9.5e-04]
# k =   550 of inf: sim.R =    -5.94450951 [best:    -5.94450951] [1.7 secs] [value_epochs =  54] [policy_epochs =  15] [  8.37 mins] [policy_lr = 9.5e-04] [value_lr = 9.5e-04]
# k =   600 of inf: sim.R =    -5.94454002 [best:    -5.94450951] [1.2 secs] [value_epochs = 150] [policy_epochs =  15] [  9.09 mins] [policy_lr = 9.4e-04] [value_lr = 9.4e-04] no improvements in 0.7 mins
# k =   650 of inf: sim.R =    -5.94455671 [best:    -5.94450951] [0.9 secs] [value_epochs = 106] [policy_epochs =  15] [  9.73 mins] [policy_lr = 9.4e-04] [value_lr = 9.4e-04] no improvements in 1.4 mins
# Terminating after 672 episodes, max time 10.0 mins reached
# R = -5.9445, time = 10.0 mins, iter = 672, policy epochs = 14.77, value epochs = 101.22
# Simulating multiple Rs

# %% [markdown]
# ## 5. <a id='toc5_'></a>[Compare life-cycle profiles](#toc0_)

# %%
ls = ['--',':','-.']

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(3,2,1)
if DO_DP: ax.plot(np.mean(model_dp.sim.c,axis=1),label='vfi',color='black',ls='-')
for i,(k,v) in enumerate(models_dl.items()):
    ax.plot(np.mean(v.sim.c.detach().cpu().numpy(),axis=1),label=f'FOC={k}',ls=ls[i],color=colors[i])
ax.set_title('$c$')
ax.legend(loc='upper left',fontsize=10)

ax = fig.add_subplot(3,2,2)
if DO_DP: ax.plot(np.mean(model_dp.sim.d1,axis=1),color='black',ls='-')
for i,(k,v) in enumerate(models_dl.items()):
    ax.plot(np.mean(v.sim.d1.detach().cpu().numpy(),axis=1),label=f'FOC={k}',ls=ls[i],color=colors[i])
ax.set_title('$d_1$')

ax = fig.add_subplot(3,2,3)
if DO_DP: ax.plot(np.mean(model_dp.sim.states[...,0],axis=1),color='black',ls='-')
for i,(k,v) in enumerate(models_dl.items()):
    ax.plot(np.mean(v.sim.states[...,0].detach().cpu().numpy(),axis=1),label=f'FOC={k}',ls=ls[i],color=colors[i])
ax.set_title('$m$')

ax = fig.add_subplot(3,2,4)
if DO_DP: ax.plot(np.mean(model_dp.sim.states_pd[...,0],axis=1),color='black',ls='-')
for i,(k,v) in enumerate(models_dl.items()):
    ax.plot(np.mean(v.sim.states_pd[...,0].detach().cpu().numpy(),axis=1),label=f'FOC={k}',ls=ls[i],color=colors[i])
ax.set_title('$a$')

ax = fig.add_subplot(3,2,5)
if DO_DP: ax.plot(np.mean(model_dp.sim.DC,axis=1),color='black',ls='-')
for i,(k,v) in enumerate(models_dl.items()):
    ax.plot(np.mean(v.sim.DC.detach().cpu().numpy(),axis=1),label=f'FOC={k}',ls=ls[i],color=colors[i])
ax.set_title('share adjusting')

fig.tight_layout()
