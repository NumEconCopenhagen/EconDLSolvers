# %% [markdown]
# # Solve

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Imports](#toc1_)
# - 2. [Settings](#toc2_)
# - 3. [Solve](#toc3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Imports](#toc0_)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from EconDLSolvers import choose_gpu
from LifeCycleModel import LifeCycleModelClass

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Settings](#toc0_)

# %%
device, _ = choose_gpu()
# Out:
# GPU 0: 79.18GB free [NVIDIA H100 80GB HBM3]
# Best GPU: 0

# %% [markdown]
# ## 3. <a id='toc3_'></a>[Solve](#toc0_)

# %%
K_time = 720.0
model = LifeCycleModelClass(algoname="DeepVPDDC", device=device, train={"K_time":K_time}) 
model.solve(do_print=True)
# Out:
# started solving: 2026-02-10 17:57:11
# k =     0 of inf: sim.R =   -20.50593758 [best:   -20.50593758] [4.6 secs] [value_epochs = 150] [policy_epochs =  15] [  0.08 mins] [policy_loss = 15.22118950] [policy_lr = 1.0e-04] [value_lr = 1.0e-03]
# k =    10 of inf: sim.R =   -19.94936752 [best:   -19.94936752] [4.6 secs] [value_epochs = 150] [policy_epochs =  15] [  0.42 mins] [policy_loss = 10.09104919] [policy_lr = 1.0e-04] [value_lr = 1.0e-03]
# k =    20 of inf: sim.R =   -19.16266251 [best:   -19.16266251] [4.6 secs] [value_epochs = 150] [policy_epochs =  15] [  0.76 mins] [policy_loss = 11.43171215] [policy_lr = 1.0e-04] [value_lr = 1.0e-03]
# k =    30 of inf: sim.R =   -18.73746681 [best:   -18.73746681] [4.6 secs] [value_epochs = 150] [policy_epochs =  15] [  1.09 mins] [policy_loss = 12.83383846] [policy_lr = 1.0e-04] [value_lr = 1.0e-03]
# ...

# %%
model.simulate_R()
model.more_simulation_outcomes()
model.get_individual_Rs()
print(model.sim.R)
# Out:
# tensor(-18.1186, device='cuda:0')
# /work/RaphaëlPaulXavierHuleux#0575/ImperfectProblemSolving/4_LargeLifeCycle/LifeCycleModel.py:670: UserWarning: torch.searchsorted(): boundary tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous boundary tensor if possible. This message will only appear once per program. (Triggered internally at /pytorch/aten/src/ATen/native/BucketizationUtils.h:38.)
#   idx_hi = torch.searchsorted(R_grid, target, right=False).squeeze(1)

# %%
model.compute_euler_errors(Nbatch_share=0.0001)

# %%
model.save('../output/LargeLifeCycleModel.pt')
